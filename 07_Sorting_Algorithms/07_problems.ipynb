# %% [markdown]
# # Topic 7: Sorting Algorithms — Practice Problems
#
# No solutions — work through them yourself!
#
# **10 problems** | Medium → Hard | Dutch National Flag, Merge Sort, Interval Problems, Custom Sorting

# %% [markdown]
# ## Problem 1: Sort Colors [Medium] — LeetCode #75
#
# Given an array `nums` with `n` objects colored red, white, or blue, sort them **in-place** so that objects of the same color are adjacent, with the colors in the order red (0), white (1), and blue (2).
#
# You must solve this without using the library's sort function. Can you do it in **one pass** using O(1) extra space?
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [2, 0, 2, 1, 1, 0]`
# - Output: `[0, 0, 1, 1, 2, 2]`
#
# **Example 2:**
# - Input: `nums = [2, 0, 1]`
# - Output: `[0, 1, 2]`
#
# ### Constraints
# - `n == len(nums)`
# - `1 <= n <= 300`
# - `nums[i]` is `0`, `1`, or `2`.
#
# ### Hints
# 1. This is the Dutch National Flag problem. Use three pointers: low, mid, high.
# 2. Move 0s to the front, 2s to the back, and 1s stay in the middle.

# %%
def sort_colors(nums: list[int]) -> None:
    """Sort in-place. Do not return anything."""
    pass


# Test cases
t1 = [2, 0, 2, 1, 1, 0]; sort_colors(t1)
print("PASS" if t1 == [0, 0, 1, 1, 2, 2] else "FAIL")

t2 = [2, 0, 1]; sort_colors(t2)
print("PASS" if t2 == [0, 1, 2] else "FAIL")

t3 = [0]; sort_colors(t3)
print("PASS" if t3 == [0] else "FAIL")

t4 = [1, 0]; sort_colors(t4)
print("PASS" if t4 == [0, 1] else "FAIL")

# %% [markdown]
# ## Problem 2: Kth Largest Element in an Array [Medium] — LeetCode #215
#
# Given an integer array `nums` and an integer `k`, return the **kth largest** element in the array.
#
# Note that it is the kth largest element in the sorted order, not the kth distinct element.
#
# Can you solve it without sorting?
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [3, 2, 1, 5, 6, 4]`, `k = 2`
# - Output: `5`
#
# **Example 2:**
# - Input: `nums = [3, 2, 3, 1, 2, 4, 5, 5, 6]`, `k = 4`
# - Output: `4`
#
# ### Constraints
# - `1 <= k <= len(nums) <= 10^5`
# - `-10^4 <= nums[i] <= 10^4`
#
# ### Hints
# 1. Quickselect algorithm: partition around a pivot and recurse on the correct half — average O(n).
# 2. Alternatively, use a min-heap of size k.

# %%
def find_kth_largest(nums: list[int], k: int) -> int:
    pass


# Test cases
print("PASS" if find_kth_largest([3, 2, 1, 5, 6, 4], 2) == 5 else "FAIL")
print("PASS" if find_kth_largest([3, 2, 3, 1, 2, 4, 5, 5, 6], 4) == 4 else "FAIL")
print("PASS" if find_kth_largest([1], 1) == 1 else "FAIL")
print("PASS" if find_kth_largest([7, 7, 7, 7], 2) == 7 else "FAIL")

# %% [markdown]
# ## Problem 3: Merge Intervals [Medium] — LeetCode #56
#
# Given an array of `intervals` where `intervals[i] = [start_i, end_i]`, merge all overlapping intervals, and return an array of the non-overlapping intervals that cover all the intervals in the input.
#
# ### Examples
#
# **Example 1:**
# - Input: `intervals = [[1,3], [2,6], [8,10], [15,18]]`
# - Output: `[[1,6], [8,10], [15,18]]`
# - Explanation: Intervals [1,3] and [2,6] overlap, merged to [1,6].
#
# **Example 2:**
# - Input: `intervals = [[1,4], [4,5]]`
# - Output: `[[1,5]]`
# - Explanation: [1,4] and [4,5] are considered overlapping.
#
# ### Constraints
# - `1 <= len(intervals) <= 10^4`
# - `intervals[i].length == 2`
# - `0 <= start_i <= end_i <= 10^4`
#
# ### Hints
# 1. Sort intervals by start time first.
# 2. Iterate and merge: if the current interval overlaps with the last merged one, extend it.

# %%
def merge_intervals(intervals: list[list[int]]) -> list[list[int]]:
    pass


# Test cases
print("PASS" if merge_intervals([[1,3],[2,6],[8,10],[15,18]]) == [[1,6],[8,10],[15,18]] else "FAIL")
print("PASS" if merge_intervals([[1,4],[4,5]]) == [[1,5]] else "FAIL")
print("PASS" if merge_intervals([[1,4],[0,4]]) == [[0,4]] else "FAIL")
print("PASS" if merge_intervals([[1,4],[2,3]]) == [[1,4]] else "FAIL")
print("PASS" if merge_intervals([[1,2]]) == [[1,2]] else "FAIL")

# %% [markdown]
# ## Problem 4: Sort List [Medium] — LeetCode #148
#
# Given the `head` of a linked list, return the list after sorting it in **ascending order**.
#
# Can you sort it in **O(n log n)** time and **O(1)** memory (i.e., constant space)?
#
# ### Examples
#
# **Example 1:**
# - Input: `head = [4, 2, 1, 3]`
# - Output: `[1, 2, 3, 4]`
#
# **Example 2:**
# - Input: `head = [-1, 5, 3, 4, 0]`
# - Output: `[-1, 0, 3, 4, 5]`
#
# **Example 3:**
# - Input: `head = []`
# - Output: `[]`
#
# ### Constraints
# - `0 <= number of nodes <= 5 * 10^4`
# - `-10^5 <= Node.val <= 10^5`
#
# ### Hints
# 1. Use merge sort on the linked list: find the middle with slow/fast pointers, split, sort each half, merge.
# 2. The merge step is similar to merging two sorted linked lists.

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def sort_list(head: ListNode | None) -> ListNode | None:
    pass


# Helpers
def build_list(vals):
    dummy = ListNode(0)
    curr = dummy
    for v in vals:
        curr.next = ListNode(v)
        curr = curr.next
    return dummy.next

def list_to_vals(head):
    vals = []
    while head:
        vals.append(head.val)
        head = head.next
    return vals

# Test cases
print("PASS" if list_to_vals(sort_list(build_list([4,2,1,3]))) == [1,2,3,4] else "FAIL")
print("PASS" if list_to_vals(sort_list(build_list([-1,5,3,4,0]))) == [-1,0,3,4,5] else "FAIL")
print("PASS" if list_to_vals(sort_list(build_list([]))) == [] else "FAIL")
print("PASS" if list_to_vals(sort_list(build_list([1]))) == [1] else "FAIL")

# %% [markdown]
# ## Problem 5: Largest Number [Medium] — LeetCode #179
#
# Given a list of non-negative integers `nums`, arrange them such that they form the **largest number** and return it as a string.
#
# Since the result may be very large, return a string instead of an integer.
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [10, 2]`
# - Output: `"210"`
#
# **Example 2:**
# - Input: `nums = [3, 30, 34, 5, 9]`
# - Output: `"9534330"`
#
# ### Constraints
# - `1 <= len(nums) <= 100`
# - `0 <= nums[i] <= 10^9`
#
# ### Hints
# 1. Define a custom comparator: for two numbers `a` and `b`, compare `str(a)+str(b)` vs `str(b)+str(a)`.
# 2. Use `functools.cmp_to_key` to sort with a custom comparator in Python.

# %%
def largest_number(nums: list[int]) -> str:
    pass


# Test cases
print("PASS" if largest_number([10, 2]) == "210" else "FAIL")
print("PASS" if largest_number([3, 30, 34, 5, 9]) == "9534330" else "FAIL")
print("PASS" if largest_number([0, 0]) == "0" else "FAIL")
print("PASS" if largest_number([1]) == "1" else "FAIL")

# %% [markdown]
# ## Problem 6: Meeting Rooms II [Medium] — LeetCode #253
#
# Given an array of meeting time intervals `intervals` where `intervals[i] = [start_i, end_i]`, return the **minimum number of conference rooms** required.
#
# ### Examples
#
# **Example 1:**
# - Input: `intervals = [[0, 30], [5, 10], [15, 20]]`
# - Output: `2`
# - Explanation: [0,30] overlaps with both others, but [5,10] and [15,20] don't overlap, so 2 rooms needed.
#
# **Example 2:**
# - Input: `intervals = [[7, 10], [2, 4]]`
# - Output: `1`
# - Explanation: No overlap, one room suffices.
#
# **Example 3:**
# - Input: `intervals = [[1, 5], [2, 6], [3, 7]]`
# - Output: `3`
#
# ### Constraints
# - `1 <= len(intervals) <= 10^4`
# - `0 <= start_i < end_i <= 10^6`
#
# ### Hints
# 1. Think of it as an event timeline: +1 when a meeting starts, -1 when it ends. The max overlap is the answer.
# 2. Alternatively, sort start and end times separately and use two pointers.

# %%
def min_meeting_rooms(intervals: list[list[int]]) -> int:
    pass


# Test cases
print("PASS" if min_meeting_rooms([[0,30],[5,10],[15,20]]) == 2 else "FAIL")
print("PASS" if min_meeting_rooms([[7,10],[2,4]]) == 1 else "FAIL")
print("PASS" if min_meeting_rooms([[1,5],[2,6],[3,7]]) == 3 else "FAIL")
print("PASS" if min_meeting_rooms([[1,2],[2,3],[3,4]]) == 1 else "FAIL")
print("PASS" if min_meeting_rooms([[1,3],[1,3],[1,3]]) == 3 else "FAIL")

# %% [markdown]
# ## Problem 7: Wiggle Sort II [Medium] — LeetCode #324
#
# Given an integer array `nums`, reorder it such that `nums[0] < nums[1] > nums[2] < nums[3] > nums[4] ...`
#
# You may assume the input always has a valid answer.
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [1, 5, 1, 1, 6, 4]`
# - Output: `[1, 6, 1, 5, 1, 4]` (one valid answer)
#
# **Example 2:**
# - Input: `nums = [1, 3, 2, 2, 3, 1]`
# - Output: `[2, 3, 1, 3, 1, 2]` (one valid answer)
#
# ### Constraints
# - `1 <= len(nums) <= 5 * 10^4`
# - `0 <= nums[i] <= 5000`
# - A valid answer always exists.
#
# ### Hints
# 1. Sort the array. Split into two halves: smaller and larger. Interleave them.
# 2. Place the smaller half at even indices and the larger half at odd indices — reverse each half to handle duplicates.

# %%
def wiggle_sort(nums: list[int]) -> None:
    """Sort in-place. Do not return anything."""
    pass


# Validation helper
def is_wiggle_sorted(nums):
    for i in range(1, len(nums)):
        if i % 2 == 1 and nums[i] <= nums[i - 1]:
            return False
        if i % 2 == 0 and nums[i] >= nums[i - 1]:
            return False
    return True

# Test cases
t1 = [1, 5, 1, 1, 6, 4]; wiggle_sort(t1)
print("PASS" if is_wiggle_sorted(t1) else "FAIL")

t2 = [1, 3, 2, 2, 3, 1]; wiggle_sort(t2)
print("PASS" if is_wiggle_sorted(t2) else "FAIL")

t3 = [4, 5, 5, 6]; wiggle_sort(t3)
print("PASS" if is_wiggle_sorted(t3) else "FAIL")

# %% [markdown]
# ## Problem 8: Count of Smaller Numbers After Self [Hard] — LeetCode #315
#
# Given an integer array `nums`, return an integer array `counts` where `counts[i]` is the number of smaller elements to the right of `nums[i]`.
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [5, 2, 6, 1]`
# - Output: `[2, 1, 1, 0]`
# - Explanation:
#   - Right of 5: [2, 1] are smaller → 2
#   - Right of 2: [1] is smaller → 1
#   - Right of 6: [1] is smaller → 1
#   - Right of 1: nothing → 0
#
# **Example 2:**
# - Input: `nums = [-1]`
# - Output: `[0]`
#
# **Example 3:**
# - Input: `nums = [-1, -1]`
# - Output: `[0, 0]`
#
# ### Constraints
# - `1 <= len(nums) <= 10^5`
# - `-10^4 <= nums[i] <= 10^4`
#
# ### Hints
# 1. Modified merge sort: during merging, count how many elements from the right half are moved before elements from the left half.
# 2. Alternatively, use a Binary Indexed Tree (BIT/Fenwick Tree) or a balanced BST.

# %%
def count_smaller(nums: list[int]) -> list[int]:
    pass


# Test cases
print("PASS" if count_smaller([5, 2, 6, 1]) == [2, 1, 1, 0] else "FAIL")
print("PASS" if count_smaller([-1]) == [0] else "FAIL")
print("PASS" if count_smaller([-1, -1]) == [0, 0] else "FAIL")
print("PASS" if count_smaller([2, 0, 1]) == [2, 0, 0] else "FAIL")
print("PASS" if count_smaller([1, 2, 3, 4]) == [0, 0, 0, 0] else "FAIL")

# %% [markdown]
# ## Problem 9: Sort an Array (Implement Merge Sort) [Medium] — LeetCode #912
#
# Given an array of integers `nums`, sort the array in ascending order and return it.
#
# You must solve the problem **without using any built-in sort functions** in O(n log n) time and with the smallest space complexity possible.
#
# **Implement merge sort.**
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [5, 2, 3, 1]`
# - Output: `[1, 2, 3, 5]`
#
# **Example 2:**
# - Input: `nums = [5, 1, 1, 2, 0, 0]`
# - Output: `[0, 0, 1, 1, 2, 5]`
#
# ### Constraints
# - `1 <= len(nums) <= 5 * 10^4`
# - `-5 * 10^4 <= nums[i] <= 5 * 10^4`
#
# ### Hints
# 1. Divide the array in half, recursively sort each half, then merge the two sorted halves.
# 2. The merge step uses two pointers to combine two sorted arrays into one.

# %%
def sort_array(nums: list[int]) -> list[int]:
    pass


# Test cases
print("PASS" if sort_array([5, 2, 3, 1]) == [1, 2, 3, 5] else "FAIL")
print("PASS" if sort_array([5, 1, 1, 2, 0, 0]) == [0, 0, 1, 1, 2, 5] else "FAIL")
print("PASS" if sort_array([1]) == [1] else "FAIL")
print("PASS" if sort_array([3, 3, 3]) == [3, 3, 3] else "FAIL")
print("PASS" if sort_array([4, 3, 2, 1]) == [1, 2, 3, 4] else "FAIL")

# %% [markdown]
# ## Problem 10: Insert Interval [Medium] — LeetCode #57
#
# You are given an array of non-overlapping intervals `intervals` where `intervals[i] = [start_i, end_i]` sorted in ascending order by `start_i`, and an interval `newInterval = [start, end]`.
#
# Insert `newInterval` into `intervals` such that `intervals` is still sorted and non-overlapping (merge overlapping intervals if necessary).
#
# Return `intervals` after the insertion.
#
# ### Examples
#
# **Example 1:**
# - Input: `intervals = [[1,3],[6,9]]`, `newInterval = [2,5]`
# - Output: `[[1,5],[6,9]]`
#
# **Example 2:**
# - Input: `intervals = [[1,2],[3,5],[6,7],[8,10],[12,16]]`, `newInterval = [4,8]`
# - Output: `[[1,2],[3,10],[12,16]]`
# - Explanation: The new interval [4,8] overlaps with [3,5],[6,7],[8,10].
#
# ### Constraints
# - `0 <= len(intervals) <= 10^4`
# - `intervals[i].length == 2`
# - `0 <= start_i <= end_i <= 10^5`
# - `intervals` is sorted by `start_i`.
# - `newInterval.length == 2`
# - `0 <= start <= end <= 10^5`
#
# ### Hints
# 1. Add all intervals that come before the new interval, then merge overlapping ones, then add the rest.
# 2. An interval `[a,b]` overlaps with `[c,d]` if `a <= d` and `c <= b`.

# %%
def insert_interval(intervals: list[list[int]], new_interval: list[int]) -> list[list[int]]:
    pass


# Test cases
print("PASS" if insert_interval([[1,3],[6,9]], [2,5]) == [[1,5],[6,9]] else "FAIL")
print("PASS" if insert_interval([[1,2],[3,5],[6,7],[8,10],[12,16]], [4,8]) == [[1,2],[3,10],[12,16]] else "FAIL")
print("PASS" if insert_interval([], [5,7]) == [[5,7]] else "FAIL")
print("PASS" if insert_interval([[1,5]], [2,3]) == [[1,5]] else "FAIL")
print("PASS" if insert_interval([[1,5]], [6,8]) == [[1,5],[6,8]] else "FAIL")
