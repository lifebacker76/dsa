# %% [markdown]
# # Topic 1: Big-O and Complexity — Practice Problems
#
# Solve these problems using the patterns from the main notebook. No solutions provided — work through them yourself!
#
# **Problems 1–4:** Analyze the time and space complexity of given code snippets.
#
# **Problems 5–8:** You're given a brute-force solution — optimize it!

# %% [markdown]
# ## Problem 1: Complexity Analysis — Nested Loop with Break
#
# Analyze the following code. What is its **time complexity** and **space complexity**?
#
# ```python
# def mystery_1(nums: list[int]) -> bool:
#     n = len(nums)
#     for i in range(n):
#         for j in range(i + 1, n):
#             if nums[i] + nums[j] == 0:
#                 return True
#     return False
# ```
#
# ### Your Task
# In the code cell below, write your analysis as comments.

# %%
# Time Complexity:  O(???)
# Space Complexity: O(???)
#
# Explanation:
# ...

# %% [markdown]
# ## Problem 2: Complexity Analysis — Halving Loop
#
# Analyze the following code. What is its **time complexity** and **space complexity**?
#
# ```python
# def mystery_2(n: int) -> int:
#     count = 0
#     while n > 1:
#         n = n // 2
#         count += 1
#     return count
# ```
#
# ### Your Task
# In the code cell below, write your analysis as comments.

# %%
# Time Complexity:  O(???)
# Space Complexity: O(???)
#
# Explanation:
# ...

# %% [markdown]
# ## Problem 3: Complexity Analysis — Recursive Function
#
# Analyze the following code. What is its **time complexity** and **space complexity**?
#
# ```python
# def mystery_3(n: int) -> int:
#     if n <= 1:
#         return n
#     return mystery_3(n - 1) + mystery_3(n - 2)
# ```
#
# ### Your Task
# In the code cell below, write your analysis as comments. Think about the recursion tree.

# %%
# Time Complexity:  O(???)
# Space Complexity: O(???)
#
# Explanation:
# ...

# %% [markdown]
# ## Problem 4: Complexity Analysis — String Building in a Loop
#
# Analyze the following code. What is its **time complexity** and **space complexity**?
#
# ```python
# def mystery_4(words: list[str]) -> str:
#     result = ""
#     for word in words:
#         result += word  # string concatenation
#     return result
# ```
#
# ### Your Task
# In the code cell below, write your analysis as comments. Remember that strings are immutable in Python!

# %%
# Time Complexity:  O(???)
# Space Complexity: O(???)
#
# Explanation (think about what happens when you do result += word):
# ...
#
# BONUS: What's a more efficient alternative?
# ...

# %% [markdown]
# ---
#
# ## Problem 5: Contains Duplicate [Easy] — LeetCode #217
#
# Given an integer array `nums`, return `True` if any value appears at least twice, and `False` if every element is distinct.
#
# ### Brute Force (O(n²) — given to you):
# ```python
# def contains_duplicate_brute(nums):
#     for i in range(len(nums)):
#         for j in range(i + 1, len(nums)):
#             if nums[i] == nums[j]:
#                 return True
#     return False
# ```
#
# ### Your Task
# **Optimize this to O(n) time.** What data structure helps you check membership in O(1)?
#
# ### Examples
# ```
# Input:  [1, 2, 3, 1]     → True
# Input:  [1, 2, 3, 4]     → False
# Input:  [1, 1, 1, 3, 3]  → True
# ```
#
# ### Hints
# 1. A set gives O(1) lookup.
# 2. Iterate once — if you've seen the number before, return True.

# %%
def contains_duplicate(nums: list[int]) -> bool:
    """Return True if any value appears at least twice. TARGET: O(n) time, O(n) space."""
    pass


# --- Test Cases ---
print("PASS" if contains_duplicate([1, 2, 3, 1]) == True else "FAIL", "| Test 1")
print("PASS" if contains_duplicate([1, 2, 3, 4]) == False else "FAIL", "| Test 2")
print("PASS" if contains_duplicate([1, 1, 1, 3, 3]) == True else "FAIL", "| Test 3")
print("PASS" if contains_duplicate([]) == False else "FAIL", "| Test 4 (empty)")
print("PASS" if contains_duplicate([7]) == False else "FAIL", "| Test 5 (single element)")

# %% [markdown]
# ## Problem 6: Two Sum [Easy] — LeetCode #1
#
# Given an array of integers `nums` and an integer `target`, return **indices** of the two numbers such that they add up to `target`. You may assume each input has exactly one solution, and you may not use the same element twice.
#
# ### Brute Force (O(n²) — given to you):
# ```python
# def two_sum_brute(nums, target):
#     for i in range(len(nums)):
#         for j in range(i + 1, len(nums)):
#             if nums[i] + nums[j] == target:
#                 return [i, j]
#     return []
# ```
#
# ### Your Task
# **Optimize this to O(n) time** using a hash map.
#
# ### Examples
# ```
# Input:  nums = [2, 7, 11, 15], target = 9  → [0, 1]
# Input:  nums = [3, 2, 4], target = 6        → [1, 2]
# Input:  nums = [3, 3], target = 6            → [0, 1]
# ```
#
# ### Hints
# 1. For each number, compute `complement = target - num`. Check if complement is already in your map.
# 2. Store `{value: index}` as you iterate.

# %%
def two_sum(nums: list[int], target: int) -> list[int]:
    """Return indices of two numbers that add up to target. TARGET: O(n) time."""
    pass


# --- Test Cases ---
print("PASS" if two_sum([2, 7, 11, 15], 9) == [0, 1] else "FAIL", "| Test 1")
print("PASS" if two_sum([3, 2, 4], 6) == [1, 2] else "FAIL", "| Test 2")
print("PASS" if two_sum([3, 3], 6) == [0, 1] else "FAIL", "| Test 3")
print("PASS" if two_sum([1, 5, 3, 7], 8) == [1, 2] else "FAIL", "| Test 4")

# %% [markdown]
# ## Problem 7: Find the Duplicate Number [Medium] — LeetCode #287
#
# Given an array of integers `nums` containing `n + 1` integers where each integer is in the range `[1, n]` inclusive, there is **exactly one** repeated number. Return this repeated number.
#
# You must solve it **without modifying** the array and using only **O(1)** extra space.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  nums = [1, 3, 4, 2, 2]
# Output: 2
# ```
#
# **Example 2:**
# ```
# Input:  nums = [3, 1, 3, 4, 2]
# Output: 3
# ```
#
# ### Constraints
# - `1 <= n <= 10^5`
# - `nums.length == n + 1`
# - `1 <= nums[i] <= n`
#
# ### Hints
# 1. Think of the array as a linked list where `nums[i]` points to index `nums[i]`. This creates a cycle.
# 2. Floyd's Tortoise and Hare algorithm can find the cycle entry point in O(n) time, O(1) space.

# %%
def find_duplicate(nums: list[int]) -> int:
    """Find the one repeated number. TARGET: O(n) time, O(1) space."""
    pass


# --- Test Cases ---
print("PASS" if find_duplicate([1, 3, 4, 2, 2]) == 2 else "FAIL", "| Test 1")
print("PASS" if find_duplicate([3, 1, 3, 4, 2]) == 3 else "FAIL", "| Test 2")
print("PASS" if find_duplicate([1, 1]) == 1 else "FAIL", "| Test 3 (minimal)")
print("PASS" if find_duplicate([2, 2, 2, 2, 2]) == 2 else "FAIL", "| Test 4 (all same)")

# %% [markdown]
# ## Problem 8: Maximum Subarray [Medium] — LeetCode #53
#
# Given an integer array `nums`, find the subarray with the largest sum, and return its sum.
#
# A **subarray** is a contiguous non-empty sequence of elements.
#
# ### Brute Force (O(n²) — given to you):
# ```python
# def max_subarray_brute(nums):
#     max_sum = float('-inf')
#     for i in range(len(nums)):
#         current_sum = 0
#         for j in range(i, len(nums)):
#             current_sum += nums[j]
#             max_sum = max(max_sum, current_sum)
#     return max_sum
# ```
#
# ### Your Task
# **Optimize this to O(n) time** using Kadane's algorithm.
#
# ### Examples
# ```
# Input:  nums = [-2, 1, -3, 4, -1, 2, 1, -5, 4]  → 6  (subarray [4, -1, 2, 1])
# Input:  nums = [1]                                 → 1
# Input:  nums = [5, 4, -1, 7, 8]                   → 23 (entire array)
# ```
#
# ### Hints
# 1. At each position, decide: extend the previous subarray or start fresh here?
# 2. `current_sum = max(nums[i], current_sum + nums[i])` — this is the heart of Kadane's.

# %%
def max_subarray(nums: list[int]) -> int:
    """Find the contiguous subarray with the largest sum. TARGET: O(n) time."""
    pass


# --- Test Cases ---
print("PASS" if max_subarray([-2,1,-3,4,-1,2,1,-5,4]) == 6 else "FAIL", "| Test 1")
print("PASS" if max_subarray([1]) == 1 else "FAIL", "| Test 2")
print("PASS" if max_subarray([5,4,-1,7,8]) == 23 else "FAIL", "| Test 3")
print("PASS" if max_subarray([-1]) == -1 else "FAIL", "| Test 4 (single negative)")
print("PASS" if max_subarray([-2, -1]) == -1 else "FAIL", "| Test 5 (all negative)")
