# %% [markdown]
# # Topic 11: Dynamic Programming — Practice Problems
#
# No solutions — work through them yourself!
#
# ---

# %%
from typing import List

# %% [markdown]
# ## Problem 1: Climbing Stairs [Easy] — LeetCode #70
#
# You are climbing a staircase. It takes `n` steps to reach the top.
#
# Each time you can either climb **1** or **2** steps. In how many distinct ways can you climb to the top?
#
# ### Examples
#
# **Example 1:**
# ```
# Input: n = 2
# Output: 2
# Explanation: (1+1) or (2)
# ```
#
# **Example 2:**
# ```
# Input: n = 3
# Output: 3
# Explanation: (1+1+1), (1+2), (2+1)
# ```
#
# **Example 3:**
# ```
# Input: n = 5
# Output: 8
# ```
#
# ### Constraints
# - `1 <= n <= 45`
#
# ### Hints
# 1. `dp[i] = dp[i-1] + dp[i-2]` — it's basically the Fibonacci sequence!
# 2. You only need the last two values, so you can optimize to O(1) space.

# %%
def climb_stairs(n: int) -> int:
    pass

# Test cases
print("PASS" if climb_stairs(2) == 2 else "FAIL")
print("PASS" if climb_stairs(3) == 3 else "FAIL")
print("PASS" if climb_stairs(5) == 8 else "FAIL")
print("PASS" if climb_stairs(1) == 1 else "FAIL")
print("PASS" if climb_stairs(10) == 89 else "FAIL")

# %% [markdown]
# ## Problem 2: House Robber [Medium] — LeetCode #198
#
# You are a professional robber planning to rob houses along a street. Each house has a certain amount of money stashed. The only constraint is that **adjacent houses have security systems connected** — if two adjacent houses are broken into on the same night, the police will be alerted.
#
# Given an integer array `nums` representing the amount of money at each house, return the **maximum amount** you can rob tonight **without alerting the police**.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: nums = [1, 2, 3, 1]
# Output: 4
# Explanation: Rob house 0 (1) + house 2 (3) = 4.
# ```
#
# **Example 2:**
# ```
# Input: nums = [2, 7, 9, 3, 1]
# Output: 12
# Explanation: Rob house 0 (2) + house 2 (9) + house 4 (1) = 12.
# ```
#
# ### Constraints
# - `1 <= nums.length <= 100`
# - `0 <= nums[i] <= 400`
#
# ### Hints
# 1. At each house, you have two choices: rob it (add its value to the best from two houses back) or skip it (carry forward the best from the previous house).
# 2. `dp[i] = max(dp[i-1], dp[i-2] + nums[i])`

# %%
def rob(nums: List[int]) -> int:
    pass

# Test cases
print("PASS" if rob([1, 2, 3, 1]) == 4 else "FAIL")
print("PASS" if rob([2, 7, 9, 3, 1]) == 12 else "FAIL")
print("PASS" if rob([0]) == 0 else "FAIL")
print("PASS" if rob([10]) == 10 else "FAIL")
print("PASS" if rob([2, 1, 1, 2]) == 4 else "FAIL")

# %% [markdown]
# ## Problem 3: Coin Change [Medium] — LeetCode #322
#
# You are given an integer array `coins` representing coins of different denominations and an integer `amount` representing a total amount of money.
#
# Return the **fewest number of coins** that you need to make up that amount. If that amount cannot be made up by any combination of the coins, return `-1`.
#
# You may assume that you have an infinite number of each kind of coin.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: coins = [1, 5, 10], amount = 12
# Output: 3
# Explanation: 10 + 1 + 1 = 12
# ```
#
# **Example 2:**
# ```
# Input: coins = [2], amount = 3
# Output: -1
# ```
#
# **Example 3:**
# ```
# Input: coins = [1], amount = 0
# Output: 0
# ```
#
# ### Constraints
# - `1 <= coins.length <= 12`
# - `1 <= coins[i] <= 2^31 - 1`
# - `0 <= amount <= 10^4`
#
# ### Hints
# 1. Build a DP array where `dp[i]` = minimum coins needed to make amount `i`.
# 2. For each amount `i`, try every coin `c`: `dp[i] = min(dp[i], dp[i - c] + 1)` if `i - c >= 0`.

# %%
def coin_change(coins: List[int], amount: int) -> int:
    pass

# Test cases
print("PASS" if coin_change([1, 5, 10], 12) == 3 else "FAIL")
print("PASS" if coin_change([2], 3) == -1 else "FAIL")
print("PASS" if coin_change([1], 0) == 0 else "FAIL")
print("PASS" if coin_change([1, 2, 5], 11) == 3 else "FAIL")
print("PASS" if coin_change([186, 419, 83, 408], 6249) == 20 else "FAIL")

# %% [markdown]
# ## Problem 4: Longest Increasing Subsequence [Medium] — LeetCode #300
#
# Given an integer array `nums`, return the length of the **longest strictly increasing subsequence**.
#
# A **subsequence** is derived from the array by deleting some or no elements without changing the order of the remaining elements.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: nums = [10, 9, 2, 5, 3, 7, 101, 18]
# Output: 4
# Explanation: [2, 3, 7, 101] or [2, 5, 7, 101]
# ```
#
# **Example 2:**
# ```
# Input: nums = [0, 1, 0, 3, 2, 3]
# Output: 4
# ```
#
# **Example 3:**
# ```
# Input: nums = [7, 7, 7, 7, 7]
# Output: 1
# ```
#
# ### Constraints
# - `1 <= nums.length <= 2500`
# - `-10^4 <= nums[i] <= 10^4`
#
# ### Hints
# 1. O(n²) DP: `dp[i]` = length of LIS ending at index `i`. For each `j < i`, if `nums[j] < nums[i]`, then `dp[i] = max(dp[i], dp[j] + 1)`.
# 2. O(n log n): Maintain a "tails" array and use binary search (via `bisect_left`) to find where each element goes.

# %%
def length_of_lis(nums: List[int]) -> int:
    pass

# Test cases
print("PASS" if length_of_lis([10, 9, 2, 5, 3, 7, 101, 18]) == 4 else "FAIL")
print("PASS" if length_of_lis([0, 1, 0, 3, 2, 3]) == 4 else "FAIL")
print("PASS" if length_of_lis([7, 7, 7, 7, 7]) == 1 else "FAIL")
print("PASS" if length_of_lis([1]) == 1 else "FAIL")
print("PASS" if length_of_lis([1, 3, 6, 7, 9, 4, 10, 5, 6]) == 6 else "FAIL")

# %% [markdown]
# ## Problem 5: Unique Paths [Medium] — LeetCode #62
#
# There is a robot on an `m x n` grid. The robot is initially at the **top-left** corner (i.e., `grid[0][0]`). The robot tries to move to the **bottom-right** corner (i.e., `grid[m-1][n-1]`). The robot can only move either **down** or **right** at any point in time.
#
# Given `m` and `n`, return the number of possible unique paths.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: m = 3, n = 7
# Output: 28
# ```
#
# **Example 2:**
# ```
# Input: m = 3, n = 2
# Output: 3
# Explanation: Right→Down→Down, Down→Down→Right, Down→Right→Down
# ```
#
# ### Constraints
# - `1 <= m, n <= 100`
#
# ### Hints
# 1. `dp[i][j]` = number of ways to reach cell `(i, j)`. Each cell can only come from above or from the left.
# 2. `dp[i][j] = dp[i-1][j] + dp[i][j-1]`. Initialize first row and first column to 1.

# %%
def unique_paths(m: int, n: int) -> int:
    pass

# Test cases
print("PASS" if unique_paths(3, 7) == 28 else "FAIL")
print("PASS" if unique_paths(3, 2) == 3 else "FAIL")
print("PASS" if unique_paths(1, 1) == 1 else "FAIL")
print("PASS" if unique_paths(7, 3) == 28 else "FAIL")
print("PASS" if unique_paths(3, 3) == 6 else "FAIL")

# %% [markdown]
# ## Problem 6: Longest Common Subsequence [Medium] — LeetCode #1143
#
# Given two strings `text1` and `text2`, return the length of their **longest common subsequence**. If there is no common subsequence, return `0`.
#
# A **subsequence** is a sequence that can be derived from a string by deleting some (or no) characters without changing the relative order of the remaining characters.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: text1 = "abcde", text2 = "ace"
# Output: 3
# Explanation: LCS is "ace".
# ```
#
# **Example 2:**
# ```
# Input: text1 = "abc", text2 = "abc"
# Output: 3
# ```
#
# **Example 3:**
# ```
# Input: text1 = "abc", text2 = "def"
# Output: 0
# ```
#
# ### Constraints
# - `1 <= text1.length, text2.length <= 1000`
# - `text1` and `text2` consist of only lowercase English characters
#
# ### Hints
# 1. Use a 2D DP table. If `text1[i-1] == text2[j-1]`, then `dp[i][j] = dp[i-1][j-1] + 1`.
# 2. Otherwise, `dp[i][j] = max(dp[i-1][j], dp[i][j-1])`.

# %%
def longest_common_subsequence(text1: str, text2: str) -> int:
    pass

# Test cases
print("PASS" if longest_common_subsequence("abcde", "ace") == 3 else "FAIL")
print("PASS" if longest_common_subsequence("abc", "abc") == 3 else "FAIL")
print("PASS" if longest_common_subsequence("abc", "def") == 0 else "FAIL")
print("PASS" if longest_common_subsequence("oxcpqrsvwf", "shmtulqrypy") == 2 else "FAIL")

# %% [markdown]
# ## Problem 7: Word Break [Medium] — LeetCode #139
#
# Given a string `s` and a dictionary of strings `wordDict`, return `true` if `s` can be segmented into a space-separated sequence of one or more dictionary words.
#
# The same word in the dictionary may be reused multiple times.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: s = "leetcode", wordDict = ["leet", "code"]
# Output: True
# Explanation: "leetcode" = "leet" + "code"
# ```
#
# **Example 2:**
# ```
# Input: s = "applepenapple", wordDict = ["apple", "pen"]
# Output: True
# Explanation: "applepenapple" = "apple" + "pen" + "apple"
# ```
#
# **Example 3:**
# ```
# Input: s = "catsandog", wordDict = ["cats", "dog", "sand", "and", "cat"]
# Output: False
# ```
#
# ### Constraints
# - `1 <= s.length <= 300`
# - `1 <= wordDict.length <= 1000`
# - `1 <= wordDict[i].length <= 20`
# - `s` and `wordDict[i]` consist of only lowercase English letters
# - All strings in `wordDict` are unique
#
# ### Hints
# 1. Use a boolean DP array: `dp[i]` = True if `s[:i]` can be segmented using dictionary words.
# 2. For each position `i`, check all words — if `dp[i - len(word)]` is True and `s[i-len(word):i] == word`, then `dp[i] = True`.

# %%
def word_break(s: str, wordDict: List[str]) -> bool:
    pass

# Test cases
print("PASS" if word_break("leetcode", ["leet", "code"]) == True else "FAIL")
print("PASS" if word_break("applepenapple", ["apple", "pen"]) == True else "FAIL")
print("PASS" if word_break("catsandog", ["cats", "dog", "sand", "and", "cat"]) == False else "FAIL")
print("PASS" if word_break("a", ["a"]) == True else "FAIL")
print("PASS" if word_break("ab", ["a"]) == False else "FAIL")

# %% [markdown]
# ## Problem 8: 0/1 Knapsack [Medium] — Classic Problem
#
# Given `n` items, each with a **weight** and a **value**, and a knapsack with capacity `W`. Find the **maximum value** you can carry in the knapsack.
#
# You cannot split items — either take an item or leave it (0/1 choice). Each item can be taken at most once.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: weights = [1, 3, 4, 5], values = [1, 4, 5, 7], capacity = 7
# Output: 9
# Explanation: Take items with weight 3 (value 4) and weight 4 (value 5) → total value = 9.
# ```
#
# **Example 2:**
# ```
# Input: weights = [2, 3, 4, 5], values = [3, 4, 5, 6], capacity = 5
# Output: 7
# Explanation: Take items with weight 2 (value 3) and weight 3 (value 4) → total value = 7.
# ```
#
# **Example 3:**
# ```
# Input: weights = [10], values = [100], capacity = 5
# Output: 0
# Explanation: The single item is too heavy.
# ```
#
# ### Constraints
# - `1 <= n <= 100`
# - `1 <= weights[i] <= 1000`
# - `1 <= values[i] <= 1000`
# - `1 <= capacity <= 1000`
#
# ### Hints
# 1. Use 2D DP: `dp[i][w]` = max value using first `i` items with capacity `w`. For each item, decide: skip it → `dp[i-1][w]`, or take it → `dp[i-1][w - weight[i]] + value[i]` (if it fits).
# 2. Can be optimized to 1D DP by iterating capacity in reverse.

# %%
def knapsack(weights: List[int], values: List[int], capacity: int) -> int:
    pass

# Test cases
print("PASS" if knapsack([1, 3, 4, 5], [1, 4, 5, 7], 7) == 9 else "FAIL")
print("PASS" if knapsack([2, 3, 4, 5], [3, 4, 5, 6], 5) == 7 else "FAIL")
print("PASS" if knapsack([10], [100], 5) == 0 else "FAIL")
print("PASS" if knapsack([1, 2, 3], [6, 10, 12], 5) == 22 else "FAIL")
print("PASS" if knapsack([], [], 10) == 0 else "FAIL")

# %% [markdown]
# ## Problem 9: Edit Distance [Medium] — LeetCode #72
#
# Given two strings `word1` and `word2`, return the minimum number of operations required to convert `word1` to `word2`.
#
# You have three operations:
# - **Insert** a character
# - **Delete** a character
# - **Replace** a character
#
# ### Examples
#
# **Example 1:**
# ```
# Input: word1 = "horse", word2 = "ros"
# Output: 3
# Explanation:
#   horse → rorse (replace h with r)
#   rorse → rose  (delete r)
#   rose  → ros   (delete e)
# ```
#
# **Example 2:**
# ```
# Input: word1 = "intention", word2 = "execution"
# Output: 5
# Explanation:
#   intention → inention  (remove t)
#   inention  → enention  (replace i with e)
#   enention  → exention  (replace n with x)
#   exention  → exection  (replace n with c)
#   exection  → execution (insert u)
# ```
#
# ### Constraints
# - `0 <= word1.length, word2.length <= 500`
# - `word1` and `word2` consist of lowercase English letters
#
# ### Hints
# 1. Classic 2D DP. `dp[i][j]` = min operations to convert `word1[:i]` to `word2[:j]`.
# 2. If characters match, `dp[i][j] = dp[i-1][j-1]`. Otherwise, take 1 + min of insert (`dp[i][j-1]`), delete (`dp[i-1][j]`), replace (`dp[i-1][j-1]`).

# %%
def min_distance(word1: str, word2: str) -> int:
    pass

# Test cases
print("PASS" if min_distance("horse", "ros") == 3 else "FAIL")
print("PASS" if min_distance("intention", "execution") == 5 else "FAIL")
print("PASS" if min_distance("", "") == 0 else "FAIL")
print("PASS" if min_distance("abc", "") == 3 else "FAIL")
print("PASS" if min_distance("", "abc") == 3 else "FAIL")

# %% [markdown]
# ## Problem 10: Partition Equal Subset Sum [Medium] — LeetCode #416
#
# Given an integer array `nums`, return `true` if you can partition the array into two subsets such that the sum of the elements in both subsets is equal.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: nums = [1, 5, 11, 5]
# Output: True
# Explanation: [1, 5, 5] and [11] both sum to 11.
# ```
#
# **Example 2:**
# ```
# Input: nums = [1, 2, 3, 5]
# Output: False
# Explanation: Total sum is 11 (odd), so equal partition is impossible.
# ```
#
# ### Constraints
# - `1 <= nums.length <= 200`
# - `1 <= nums[i] <= 100`
#
# ### Hints
# 1. If total sum is odd, return False immediately. Otherwise, this reduces to: "can we find a subset that sums to `total // 2`?"
# 2. This is a variant of the 0/1 Knapsack problem. Use a boolean DP set or array.

# %%
def can_partition(nums: List[int]) -> bool:
    pass

# Test cases
print("PASS" if can_partition([1, 5, 11, 5]) == True else "FAIL")
print("PASS" if can_partition([1, 2, 3, 5]) == False else "FAIL")
print("PASS" if can_partition([1, 1]) == True else "FAIL")
print("PASS" if can_partition([1, 2, 5]) == False else "FAIL")
print("PASS" if can_partition([3, 3, 3, 4, 5]) == True else "FAIL")

# %% [markdown]
# ## Problem 11: Best Time to Buy and Sell Stock with Cooldown [Medium] — LeetCode #309
#
# You are given an array `prices` where `prices[i]` is the price of a given stock on the `i`th day.
#
# Find the maximum profit you can achieve. You may complete as many transactions as you like (buy one and sell one share of the stock multiple times) with the following restriction:
#
# After you sell your stock, you cannot buy stock on the next day (i.e., **cooldown of one day**).
#
# ### Examples
#
# **Example 1:**
# ```
# Input: prices = [1, 2, 3, 0, 2]
# Output: 3
# Explanation: Buy day 0, sell day 2 (profit=2), cooldown day 3, buy day 3, sell day 4 (profit=2). Total = 3.
# ```
#
# **Example 2:**
# ```
# Input: prices = [1]
# Output: 0
# ```
#
# ### Constraints
# - `1 <= prices.length <= 5000`
# - `0 <= prices[i] <= 1000`
#
# ### Hints
# 1. Use state machine DP with three states: `hold` (holding stock), `sold` (just sold), `rest` (cooldown/no stock).
# 2. Transitions: `hold = max(hold, rest - price)`, `sold = hold + price`, `rest = max(rest, sold)`.

# %%
def max_profit_cooldown(prices: List[int]) -> int:
    pass

# Test cases
print("PASS" if max_profit_cooldown([1, 2, 3, 0, 2]) == 3 else "FAIL")
print("PASS" if max_profit_cooldown([1]) == 0 else "FAIL")
print("PASS" if max_profit_cooldown([1, 2, 4]) == 3 else "FAIL")
print("PASS" if max_profit_cooldown([2, 1]) == 0 else "FAIL")
print("PASS" if max_profit_cooldown([6, 1, 3, 2, 4, 7]) == 6 else "FAIL")

# %% [markdown]
# ## Problem 12: Burst Balloons [Hard] — LeetCode #312
#
# You are given `n` balloons, indexed from `0` to `n - 1`. Each balloon is painted with a number on it represented by an array `nums`. You are asked to burst all the balloons.
#
# If you burst the `i`th balloon, you will get `nums[i-1] * nums[i] * nums[i+1]` coins. If `i-1` or `i+1` goes out of bounds, treat it as if there is a balloon with a `1` painted on it.
#
# Return the **maximum** coins you can collect by bursting the balloons wisely.
#
# ### Examples
#
# **Example 1:**
# ```
# Input: nums = [3, 1, 5, 8]
# Output: 167
# Explanation:
#   nums = [3,1,5,8] → burst 1 → [3,5,8] → coins += 3*1*5 = 15
#   nums = [3,5,8]   → burst 5 → [3,8]   → coins += 3*5*8 = 120
#   nums = [3,8]     → burst 3 → [8]     → coins += 1*3*8 = 24
#   nums = [8]       → burst 8 → []      → coins += 1*8*1 = 8
#   Total = 15 + 120 + 24 + 8 = 167
# ```
#
# **Example 2:**
# ```
# Input: nums = [1, 5]
# Output: 10
# ```
#
# ### Constraints
# - `n == nums.length`
# - `1 <= n <= 300`
# - `0 <= nums[i] <= 100`
#
# ### Hints
# 1. Think backwards: instead of which balloon to burst first, think about which balloon to burst **last** in a range.
# 2. Use interval DP: `dp[left][right]` = max coins from bursting all balloons between `left` and `right` (exclusive). The last balloon burst in range `(left, right)` is `k`, giving coins = `nums[left] * nums[k] * nums[right] + dp[left][k] + dp[k][right]`.

# %%
def max_coins(nums: List[int]) -> int:
    pass

# Test cases
print("PASS" if max_coins([3, 1, 5, 8]) == 167 else "FAIL")
print("PASS" if max_coins([1, 5]) == 10 else "FAIL")
print("PASS" if max_coins([5]) == 5 else "FAIL")
print("PASS" if max_coins([1, 2, 3]) == 12 else "FAIL")
