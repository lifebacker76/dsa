# %% [markdown]
# # 02 — Classical ML Exercises
#
# 12 problems covering regression, classification, clustering, evaluation, and feature engineering.
# No solutions provided — work through them yourself.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import (
    fetch_california_housing, load_iris, load_digits, load_wine,
    make_blobs, make_classification
)
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import (
    mean_squared_error, r2_score, accuracy_score,
    confusion_matrix, roc_curve, auc
)

plt.rcParams['figure.figsize'] = (8, 5)
np.random.seed(42)

# %% [markdown]
# ---
# ## Problem 1 — Linear Regression on California Housing
#
# 1. Load the California housing dataset
# 2. Split into train/test (80/20)
# 3. Train a `LinearRegression` model
# 4. Evaluate with **RMSE** and **R²** on the test set
# 5. Print both metrics

# %%
# Problem 1 — Your code here

# %% [markdown]
# ---
# ## Problem 2 — Gradient Descent from Scratch
#
# 1. Generate simple linear data: `y = 3x + 7 + noise`
# 2. Implement gradient descent to find `w` and `b`
# 3. Plot the loss curve (MSE vs epoch)
# 4. Plot the fitted line on the data
# 5. Compare your `w, b` with sklearn's `LinearRegression`

# %%
# Problem 2 — Your code here

# %% [markdown]
# ---
# ## Problem 3 — Logistic Regression Decision Boundary
#
# 1. Load the iris dataset (use only the first 2 features for 2D visualization)
# 2. Train a `LogisticRegression` classifier
# 3. Plot the **decision boundary** with a mesh grid
# 4. Color the regions and overlay the actual data points
# 5. Report the training accuracy

# %%
# Problem 3 — Your code here

# %% [markdown]
# ---
# ## Problem 4 — KNN: Accuracy vs k
#
# 1. Load the iris dataset (all features)
# 2. Split into train/test
# 3. Train `KNeighborsClassifier` for k = 1, 5, 15, 50
# 4. Plot a line chart: **accuracy (train and test) vs k**
# 5. Which k gives the best test accuracy?

# %%
# Problem 4 — Your code here

# %% [markdown]
# ---
# ## Problem 5 — Random Forest Feature Importances
#
# 1. Load the wine dataset
# 2. Train a `RandomForestClassifier` with 100 trees
# 3. Extract `feature_importances_`
# 4. Create a **horizontal bar chart** of feature importances, sorted
# 5. Which 3 features are most important?

# %%
# Problem 5 — Your code here

# %% [markdown]
# ---
# ## Problem 6 — K-Means Clustering
#
# 1. Generate 2D blob data with `make_blobs` (4 centers)
# 2. Apply `KMeans` with k=4
# 3. Plot the clusters colored by label
# 4. Mark the centroids on the plot
# 5. Bonus: plot the **elbow curve** (inertia vs k) for k=1..10

# %%
# Problem 6 — Your code here

# %% [markdown]
# ---
# ## Problem 7 — PCA Visualization of Digits
#
# 1. Load the digits dataset (64-dimensional)
# 2. Apply `PCA` to reduce to 2 components
# 3. Create a scatter plot colored by digit label
# 4. Print the explained variance ratio of each component
# 5. How much total variance is captured in 2 components?

# %%
# Problem 7 — Your code here

# %% [markdown]
# ---
# ## Problem 8 — Confusion Matrix
#
# 1. Load the breast cancer dataset
# 2. Train a classifier of your choice
# 3. Compute the confusion matrix on the test set
# 4. Plot it as a **heatmap** (use seaborn or matplotlib)
# 5. Report precision, recall, and F1 for each class

# %%
# Problem 8 — Your code here

# %% [markdown]
# ---
# ## Problem 9 — ROC Curves for 3 Models
#
# 1. Load the breast cancer dataset
# 2. Train 3 different classifiers (e.g., Logistic Regression, Random Forest, KNN)
# 3. Compute ROC curves for each
# 4. Plot all 3 ROC curves **on the same plot** with their AUC in the legend
# 5. Include the random baseline diagonal

# %%
# Problem 9 — Your code here

# %% [markdown]
# ---
# ## Problem 10 — GridSearchCV for Decision Tree
#
# 1. Load the iris dataset
# 2. Define a parameter grid:
#    - `max_depth`: [1, 3, 5, 10, None]
#    - `min_samples_split`: [2, 5, 10, 20]
# 3. Run `GridSearchCV` with 5-fold CV
# 4. Print the best parameters and best score
# 5. Evaluate the best model on the test set

# %%
# Problem 10 — Your code here

# %% [markdown]
# ---
# ## Problem 11 — Full sklearn Pipeline
#
# Build a `Pipeline` that chains:
# 1. `StandardScaler` for numerical features
# 2. `OneHotEncoder` for categorical features (use `ColumnTransformer`)
# 3. A classifier of your choice
#
# Create a synthetic dataset with both numerical and categorical columns.
# Run 5-fold cross-validation through the pipeline and report accuracy.

# %%
# Problem 11 — Your code here

# %% [markdown]
# ---
# ## Problem 12 — Feature Engineering Challenge
#
# 1. Load the California housing dataset as a DataFrame
# 2. Engineer **3 new features** from existing columns (ratios, interactions, etc.)
# 3. Train a model with original features → record R²
# 4. Train the same model with original + new features → record R²
# 5. Show that your engineered features **improved** the score

# %%
# Problem 12 — Your code here
