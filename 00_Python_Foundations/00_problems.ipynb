# %% [markdown]
# # Topic 0: Python Foundations — Practice Problems
#
# Solve these problems using the patterns from the main notebook. No solutions provided — work through them yourself!

# %% [markdown]
# ## Problem 1: Reverse String [Easy] — LeetCode #344 (Adapted)
#
# Write a function that reverses a list of characters **in-place**. Do not allocate extra space for another list — you must modify the input list by using O(1) extra memory.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  s = ['h', 'e', 'l', 'l', 'o']
# Output: ['o', 'l', 'l', 'e', 'h']
# ```
#
# **Example 2:**
# ```
# Input:  s = ['H', 'a', 'n', 'n', 'a', 'h']
# Output: ['h', 'a', 'n', 'n', 'a', 'H']
# ```
#
# ### Constraints
# - `1 <= len(s) <= 10^5`
# - Each `s[i]` is a printable ASCII character
#
# ### Hints
# 1. Use two pointers — one at the start, one at the end.
# 2. Swap and move inward until they meet.

# %%
def reverse_string(s: list[str]) -> None:
    """Reverse the list in-place. Do not return anything."""
    pass


# --- Test Cases ---
t1 = ['h', 'e', 'l', 'l', 'o']
reverse_string(t1)
print("PASS" if t1 == ['o', 'l', 'l', 'e', 'h'] else "FAIL", "| Test 1")

t2 = ['H', 'a', 'n', 'n', 'a', 'h']
reverse_string(t2)
print("PASS" if t2 == ['h', 'a', 'n', 'n', 'a', 'H'] else "FAIL", "| Test 2")

t3 = ['A']
reverse_string(t3)
print("PASS" if t3 == ['A'] else "FAIL", "| Test 3 (single element)")

t4 = ['a', 'b']
reverse_string(t4)
print("PASS" if t4 == ['b', 'a'] else "FAIL", "| Test 4 (two elements)")

# %% [markdown]
# ## Problem 2: Move Zeroes [Easy] — LeetCode #283
#
# Given an integer array `nums`, move all `0`'s to the end of it while maintaining the relative order of the non-zero elements. You must do this **in-place** without making a copy of the array.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  nums = [0, 1, 0, 3, 12]
# Output: [1, 3, 12, 0, 0]
# ```
#
# **Example 2:**
# ```
# Input:  nums = [0]
# Output: [0]
# ```
#
# **Example 3:**
# ```
# Input:  nums = [1, 2, 3]
# Output: [1, 2, 3]
# ```
#
# ### Constraints
# - `1 <= len(nums) <= 10^4`
# - `-2^31 <= nums[i] <= 2^31 - 1`
#
# ### Hints
# 1. Use a "write pointer" that tracks where the next non-zero element should go.
# 2. Iterate with a read pointer; when you find a non-zero, swap it to the write position.

# %%
def move_zeroes(nums: list[int]) -> None:
    """Move all zeroes to the end in-place. Do not return anything."""
    pass


# --- Test Cases ---
t1 = [0, 1, 0, 3, 12]
move_zeroes(t1)
print("PASS" if t1 == [1, 3, 12, 0, 0] else "FAIL", "| Test 1")

t2 = [0]
move_zeroes(t2)
print("PASS" if t2 == [0] else "FAIL", "| Test 2")

t3 = [1, 2, 3]
move_zeroes(t3)
print("PASS" if t3 == [1, 2, 3] else "FAIL", "| Test 3 (no zeroes)")

t4 = [0, 0, 0, 1]
move_zeroes(t4)
print("PASS" if t4 == [1, 0, 0, 0] else "FAIL", "| Test 4 (all zeroes except last)")

# %% [markdown]
# ## Problem 3: Plus One [Easy] — LeetCode #66
#
# You are given a large integer represented as an integer array `digits`, where each `digits[i]` is the `i`-th digit of the integer. The digits are ordered from most significant to least significant (left to right). The large integer does not contain any leading 0's.
#
# Increment the large integer by one and return the resulting array of digits.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  digits = [1, 2, 3]
# Output: [1, 2, 4]
# Explanation: 123 + 1 = 124
# ```
#
# **Example 2:**
# ```
# Input:  digits = [9, 9, 9]
# Output: [1, 0, 0, 0]
# Explanation: 999 + 1 = 1000
# ```
#
# **Example 3:**
# ```
# Input:  digits = [1, 9]
# Output: [2, 0]
# Explanation: 19 + 1 = 20
# ```
#
# ### Constraints
# - `1 <= len(digits) <= 100`
# - `0 <= digits[i] <= 9`
#
# ### Hints
# 1. Start from the last digit and work backwards — this is like manual addition.
# 2. The tricky case is carrying over (e.g., 9 → 0 with carry).

# %%
def plus_one(digits: list[int]) -> list[int]:
    """Increment the number represented by digits by one."""
    pass


# --- Test Cases ---
print("PASS" if plus_one([1, 2, 3]) == [1, 2, 4] else "FAIL", "| Test 1")
print("PASS" if plus_one([9, 9, 9]) == [1, 0, 0, 0] else "FAIL", "| Test 2 (all nines)")
print("PASS" if plus_one([1, 9]) == [2, 0] else "FAIL", "| Test 3 (carry)")
print("PASS" if plus_one([0]) == [1] else "FAIL", "| Test 4 (zero)")
print("PASS" if plus_one([8, 9, 9]) == [9, 0, 0] else "FAIL", "| Test 5")

# %% [markdown]
# ## Problem 4: Find All Numbers Disappeared in an Array [Easy] — LeetCode #448
#
# Given an array `nums` of `n` integers where `nums[i]` is in the range `[1, n]`, return an array of all the integers in the range `[1, n]` that do not appear in `nums`.
#
# **Follow-up:** Can you do it without extra space and in O(n) runtime? You may assume the returned list does not count as extra space.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  nums = [4, 3, 2, 7, 8, 2, 3, 1]
# Output: [5, 6]
# ```
#
# **Example 2:**
# ```
# Input:  nums = [1, 1]
# Output: [2]
# ```
#
# ### Constraints
# - `n == len(nums)`
# - `1 <= n <= 10^5`
# - `1 <= nums[i] <= n`
#
# ### Hints
# 1. A set-based approach gives O(n) time with O(n) space.
# 2. For O(1) extra space: use the array itself as a "hash map" by marking visited indices as negative.

# %%
def find_disappeared_numbers(nums: list[int]) -> list[int]:
    """Return all numbers in [1, n] missing from the array."""
    pass


# --- Test Cases ---
print("PASS" if sorted(find_disappeared_numbers([4,3,2,7,8,2,3,1])) == [5, 6] else "FAIL", "| Test 1")
print("PASS" if find_disappeared_numbers([1, 1]) == [2] else "FAIL", "| Test 2")
print("PASS" if find_disappeared_numbers([1]) == [] else "FAIL", "| Test 3 (no missing)")
print("PASS" if sorted(find_disappeared_numbers([1, 1, 1, 1])) == [2, 3, 4] else "FAIL", "| Test 4")

# %% [markdown]
# ## Problem 5: Single Number [Easy] — LeetCode #136
#
# Given a non-empty array of integers `nums`, every element appears **twice** except for one. Find that single one.
#
# You must implement a solution with **O(n)** time complexity and **O(1)** extra space complexity.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  nums = [2, 2, 1]
# Output: 1
# ```
#
# **Example 2:**
# ```
# Input:  nums = [4, 1, 2, 1, 2]
# Output: 4
# ```
#
# **Example 3:**
# ```
# Input:  nums = [1]
# Output: 1
# ```
#
# ### Constraints
# - `1 <= len(nums) <= 3 * 10^4`
# - `-3 * 10^4 <= nums[i] <= 3 * 10^4`
# - Every element appears exactly twice except for one
#
# ### Hints
# 1. Think about the XOR bitwise operation: `a ^ a = 0` and `a ^ 0 = a`.
# 2. XOR all elements together — pairs cancel out.

# %%
def single_number(nums: list[int]) -> int:
    """Find the element that appears only once."""
    pass


# --- Test Cases ---
print("PASS" if single_number([2, 2, 1]) == 1 else "FAIL", "| Test 1")
print("PASS" if single_number([4, 1, 2, 1, 2]) == 4 else "FAIL", "| Test 2")
print("PASS" if single_number([1]) == 1 else "FAIL", "| Test 3 (single element)")
print("PASS" if single_number([10, 20, 10]) == 20 else "FAIL", "| Test 4")

# %% [markdown]
# ## Problem 6: Intersection of Two Arrays II [Easy] — LeetCode #350
#
# Given two integer arrays `nums1` and `nums2`, return an array of their intersection. Each element in the result must appear as many times as it shows in both arrays. You may return the result in any order.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  nums1 = [1, 2, 2, 1], nums2 = [2, 2]
# Output: [2, 2]
# ```
#
# **Example 2:**
# ```
# Input:  nums1 = [4, 9, 5], nums2 = [9, 4, 9, 8, 4]
# Output: [4, 9]  (order doesn't matter)
# ```
#
# ### Constraints
# - `1 <= len(nums1), len(nums2) <= 1000`
# - `0 <= nums1[i], nums2[i] <= 1000`
#
# ### Hints
# 1. Use a dictionary (Counter) to count occurrences of each number in one array.
# 2. Iterate through the second array and collect matches, decrementing counts.

# %%
def intersect(nums1: list[int], nums2: list[int]) -> list[int]:
    """Return the intersection of two arrays (including duplicates)."""
    pass


# --- Test Cases ---
print("PASS" if sorted(intersect([1,2,2,1], [2,2])) == [2, 2] else "FAIL", "| Test 1")
print("PASS" if sorted(intersect([4,9,5], [9,4,9,8,4])) == [4, 9] else "FAIL", "| Test 2")
print("PASS" if intersect([1, 2, 3], [4, 5, 6]) == [] else "FAIL", "| Test 3 (no overlap)")
print("PASS" if sorted(intersect([1,1,1], [1,1])) == [1, 1] else "FAIL", "| Test 4 (frequency matters)")

# %% [markdown]
# ## Problem 7: Valid Anagram [Easy] — LeetCode #242
#
# Given two strings `s` and `t`, return `True` if `t` is an anagram of `s`, and `False` otherwise.
#
# An **anagram** is a word formed by rearranging the letters of a different word, using all the original letters exactly once.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  s = "anagram", t = "nagaram"
# Output: True
# ```
#
# **Example 2:**
# ```
# Input:  s = "rat", t = "car"
# Output: False
# ```
#
# ### Constraints
# - `1 <= len(s), len(t) <= 5 * 10^4`
# - `s` and `t` consist of lowercase English letters
#
# ### Hints
# 1. Count character frequencies in both strings and compare.
# 2. Python's `collections.Counter` makes this a one-liner — but try doing it manually first!

# %%
def is_anagram(s: str, t: str) -> bool:
    """Return True if t is an anagram of s."""
    pass


# --- Test Cases ---
print("PASS" if is_anagram("anagram", "nagaram") == True else "FAIL", "| Test 1")
print("PASS" if is_anagram("rat", "car") == False else "FAIL", "| Test 2")
print("PASS" if is_anagram("a", "a") == True else "FAIL", "| Test 3 (single char)")
print("PASS" if is_anagram("ab", "a") == False else "FAIL", "| Test 4 (different length)")
print("PASS" if is_anagram("listen", "silent") == True else "FAIL", "| Test 5")

# %% [markdown]
# ## Problem 8: Merge Sorted Array [Easy] — LeetCode #88
#
# You are given two integer arrays `nums1` and `nums2`, sorted in non-decreasing order, and two integers `m` and `n`, representing the number of elements in `nums1` and `nums2` respectively.
#
# Merge `nums2` into `nums1` as one sorted array **in-place**.
#
# `nums1` has a length of `m + n`, where the last `n` elements are set to 0 and should be ignored.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  nums1 = [1, 2, 3, 0, 0, 0], m = 3, nums2 = [2, 5, 6], n = 3
# Output: [1, 2, 2, 3, 5, 6]
# ```
#
# **Example 2:**
# ```
# Input:  nums1 = [1], m = 1, nums2 = [], n = 0
# Output: [1]
# ```
#
# **Example 3:**
# ```
# Input:  nums1 = [0], m = 0, nums2 = [1], n = 1
# Output: [1]
# ```
#
# ### Constraints
# - `nums1.length == m + n`
# - `nums2.length == n`
# - `0 <= m, n <= 200`
#
# ### Hints
# 1. Start merging from the **end** of both arrays — fill `nums1` from right to left.
# 2. Use three pointers: one for end of `nums1`'s real elements, one for end of `nums2`, and one for the write position.

# %%
def merge(nums1: list[int], m: int, nums2: list[int], n: int) -> None:
    """Merge nums2 into nums1 in-place. Do not return anything."""
    pass


# --- Test Cases ---
t1 = [1, 2, 3, 0, 0, 0]
merge(t1, 3, [2, 5, 6], 3)
print("PASS" if t1 == [1, 2, 2, 3, 5, 6] else "FAIL", "| Test 1")

t2 = [1]
merge(t2, 1, [], 0)
print("PASS" if t2 == [1] else "FAIL", "| Test 2")

t3 = [0]
merge(t3, 0, [1], 1)
print("PASS" if t3 == [1] else "FAIL", "| Test 3")

t4 = [4, 5, 6, 0, 0, 0]
merge(t4, 3, [1, 2, 3], 3)
print("PASS" if t4 == [1, 2, 3, 4, 5, 6] else "FAIL", "| Test 4 (nums2 all smaller)")
