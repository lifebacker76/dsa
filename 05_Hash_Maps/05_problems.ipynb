# %% [markdown]
# # Topic 5: Hash Maps & Sets — Practice Problems
#
# No solutions — work through them yourself!
#
# **10 problems** | Easy → Hard | Hash Maps, Hash Sets, Frequency Counting, Sliding Window

# %% [markdown]
# ## Problem 1: Contains Duplicate [Easy] — LeetCode #217
#
# Given an integer array `nums`, return `True` if any value appears **at least twice** in the array, and `False` if every element is distinct.
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [1, 2, 3, 1]`
# - Output: `True`
# - Explanation: `1` appears at index 0 and index 3.
#
# **Example 2:**
# - Input: `nums = [1, 2, 3, 4]`
# - Output: `False`
# - Explanation: All elements are distinct.
#
# **Example 3:**
# - Input: `nums = [1, 1, 1, 3, 3, 4, 3, 2, 4, 2]`
# - Output: `True`
#
# ### Constraints
# - `1 <= len(nums) <= 10^5`
# - `-10^9 <= nums[i] <= 10^9`
#
# ### Hints
# 1. What data structure allows O(1) lookup to check if you've seen a number before?
# 2. A set automatically handles duplicates — what happens when you compare its size to the array's size?

# %%
def contains_duplicate(nums: list[int]) -> bool:
    pass


# Test cases
print("PASS" if contains_duplicate([1, 2, 3, 1]) == True else "FAIL")
print("PASS" if contains_duplicate([1, 2, 3, 4]) == False else "FAIL")
print("PASS" if contains_duplicate([1, 1, 1, 3, 3, 4, 3, 2, 4, 2]) == True else "FAIL")
print("PASS" if contains_duplicate([]) == False else "FAIL")
print("PASS" if contains_duplicate([7]) == False else "FAIL")

# %% [markdown]
# ## Problem 2: Happy Number [Easy] — LeetCode #202
#
# Write an algorithm to determine if a number `n` is **happy**.
#
# A **happy number** is defined by the following process:
# - Starting with any positive integer, replace the number by the sum of the squares of its digits.
# - Repeat the process until the number equals `1` (where it will stay), or it **loops endlessly in a cycle** which does not include `1`.
# - Numbers for which this process ends in `1` are happy.
#
# Return `True` if `n` is a happy number, `False` otherwise.
#
# ### Examples
#
# **Example 1:**
# - Input: `n = 19`
# - Output: `True`
# - Explanation: 1² + 9² = 82 → 8² + 2² = 68 → 6² + 8² = 100 → 1² + 0² + 0² = 1
#
# **Example 2:**
# - Input: `n = 2`
# - Output: `False`
# - Explanation: The process cycles: 2 → 4 → 16 → 37 → 58 → 89 → 145 → 42 → 20 → 4 → ...
#
# ### Constraints
# - `1 <= n <= 2^31 - 1`
#
# ### Hints
# 1. Use a set to track numbers you've already seen — if you see a repeat, you're in a cycle.
# 2. Alternatively, think about Floyd's cycle detection (slow/fast pointer) on the sequence of sums.

# %%
def is_happy(n: int) -> bool:
    pass


# Test cases
print("PASS" if is_happy(19) == True else "FAIL")
print("PASS" if is_happy(2) == False else "FAIL")
print("PASS" if is_happy(1) == True else "FAIL")
print("PASS" if is_happy(7) == True else "FAIL")
print("PASS" if is_happy(4) == False else "FAIL")

# %% [markdown]
# ## Problem 3: Isomorphic Strings [Easy] — LeetCode #205
#
# Given two strings `s` and `t`, determine if they are **isomorphic**.
#
# Two strings are isomorphic if the characters in `s` can be replaced to get `t`, with the following rules:
# - Each character maps to exactly one other character (one-to-one mapping).
# - No two characters may map to the same character.
# - A character may map to itself.
# - The order of characters is preserved.
#
# ### Examples
#
# **Example 1:**
# - Input: `s = "egg"`, `t = "add"`
# - Output: `True`
# - Explanation: `e -> a`, `g -> d`. The mapping is consistent.
#
# **Example 2:**
# - Input: `s = "foo"`, `t = "bar"`
# - Output: `False`
# - Explanation: `o` would need to map to both `a` and `r`.
#
# **Example 3:**
# - Input: `s = "paper"`, `t = "title"`
# - Output: `True`
#
# ### Constraints
# - `1 <= len(s) <= 5 * 10^4`
# - `len(s) == len(t)`
# - `s` and `t` consist of any valid ASCII character.
#
# ### Hints
# 1. Use two hash maps: one for s→t mapping and one for t→s mapping.
# 2. At each position, check that both mappings are consistent.

# %%
def is_isomorphic(s: str, t: str) -> bool:
    pass


# Test cases
print("PASS" if is_isomorphic("egg", "add") == True else "FAIL")
print("PASS" if is_isomorphic("foo", "bar") == False else "FAIL")
print("PASS" if is_isomorphic("paper", "title") == True else "FAIL")
print("PASS" if is_isomorphic("badc", "baba") == False else "FAIL")
print("PASS" if is_isomorphic("a", "a") == True else "FAIL")

# %% [markdown]
# ## Problem 4: Word Pattern [Easy] — LeetCode #290
#
# Given a `pattern` and a string `s`, find if `s` follows the same pattern.
#
# "Follows" means a **full match** — there is a bijection (one-to-one correspondence) between a letter in `pattern` and a non-empty word in `s`.
#
# ### Examples
#
# **Example 1:**
# - Input: `pattern = "abba"`, `s = "dog cat cat dog"`
# - Output: `True`
# - Explanation: `a -> dog`, `b -> cat`.
#
# **Example 2:**
# - Input: `pattern = "abba"`, `s = "dog cat cat fish"`
# - Output: `False`
# - Explanation: `a` maps to `dog` initially but would need to map to `fish`.
#
# **Example 3:**
# - Input: `pattern = "aaaa"`, `s = "dog cat cat dog"`
# - Output: `False`
# - Explanation: `a` can't map to both `dog` and `cat`.
#
# ### Constraints
# - `1 <= len(pattern) <= 300`
# - `pattern` contains only lower-case English letters.
# - `1 <= len(s) <= 3000`
# - `s` contains only lower-case English letters and spaces.
#
# ### Hints
# 1. Split the string into words and check length matches pattern length first.
# 2. This is essentially the same as Isomorphic Strings but between characters and words.

# %%
def word_pattern(pattern: str, s: str) -> bool:
    pass


# Test cases
print("PASS" if word_pattern("abba", "dog cat cat dog") == True else "FAIL")
print("PASS" if word_pattern("abba", "dog cat cat fish") == False else "FAIL")
print("PASS" if word_pattern("aaaa", "dog cat cat dog") == False else "FAIL")
print("PASS" if word_pattern("abba", "dog dog dog dog") == False else "FAIL")
print("PASS" if word_pattern("abc", "dog cat fish") == True else "FAIL")

# %% [markdown]
# ## Problem 5: Top K Frequent Elements [Medium] — LeetCode #347
#
# Given an integer array `nums` and an integer `k`, return the `k` most frequent elements. You may return the answer in **any order**.
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [1, 1, 1, 2, 2, 3]`, `k = 2`
# - Output: `[1, 2]`
# - Explanation: `1` appears 3 times, `2` appears 2 times.
#
# **Example 2:**
# - Input: `nums = [1]`, `k = 1`
# - Output: `[1]`
#
# **Example 3:**
# - Input: `nums = [4, 4, 4, 1, 1, 2, 2, 2, 3]`, `k = 2`
# - Output: `[4, 2]` (or `[2, 4]`)
#
# ### Constraints
# - `1 <= len(nums) <= 10^5`
# - `-10^4 <= nums[i] <= 10^4`
# - `k` is in the range `[1, number of unique elements]`
# - The answer is guaranteed to be unique.
#
# ### Hints
# 1. Use a hash map to count frequencies, then think about how to efficiently find the top k.
# 2. Bucket sort approach: create buckets indexed by frequency — bucket[i] holds elements appearing i times.

# %%
def top_k_frequent(nums: list[int], k: int) -> list[int]:
    pass


# Test cases
print("PASS" if set(top_k_frequent([1, 1, 1, 2, 2, 3], 2)) == {1, 2} else "FAIL")
print("PASS" if set(top_k_frequent([1], 1)) == {1} else "FAIL")
print("PASS" if set(top_k_frequent([4, 4, 4, 1, 1, 2, 2, 2, 3], 2)) == {4, 2} else "FAIL")
print("PASS" if set(top_k_frequent([1, 2], 2)) == {1, 2} else "FAIL")

# %% [markdown]
# ## Problem 6: Longest Consecutive Sequence [Medium] — LeetCode #128
#
# Given an unsorted array of integers `nums`, return the length of the **longest consecutive elements sequence**.
#
# You must write an algorithm that runs in **O(n)** time.
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [100, 4, 200, 1, 3, 2]`
# - Output: `4`
# - Explanation: The longest consecutive sequence is `[1, 2, 3, 4]`, length = 4.
#
# **Example 2:**
# - Input: `nums = [0, 3, 7, 2, 5, 8, 4, 6, 0, 1]`
# - Output: `9`
# - Explanation: The longest consecutive sequence is `[0, 1, 2, 3, 4, 5, 6, 7, 8]`.
#
# ### Constraints
# - `0 <= len(nums) <= 10^5`
# - `-10^9 <= nums[i] <= 10^9`
#
# ### Hints
# 1. Put all numbers in a set. A number is the start of a sequence if `num - 1` is NOT in the set.
# 2. For each sequence start, count how far the consecutive sequence extends.

# %%
def longest_consecutive(nums: list[int]) -> int:
    pass


# Test cases
print("PASS" if longest_consecutive([100, 4, 200, 1, 3, 2]) == 4 else "FAIL")
print("PASS" if longest_consecutive([0, 3, 7, 2, 5, 8, 4, 6, 0, 1]) == 9 else "FAIL")
print("PASS" if longest_consecutive([]) == 0 else "FAIL")
print("PASS" if longest_consecutive([1]) == 1 else "FAIL")
print("PASS" if longest_consecutive([1, 2, 0, 1]) == 3 else "FAIL")

# %% [markdown]
# ## Problem 7: Group Anagrams [Medium] — LeetCode #49
#
# Given an array of strings `strs`, group the **anagrams** together. You can return the answer in any order.
#
# An **anagram** is a word formed by rearranging the letters of another word, using all the original letters exactly once.
#
# ### Examples
#
# **Example 1:**
# - Input: `strs = ["eat", "tea", "tan", "ate", "nat", "bat"]`
# - Output: `[["bat"], ["nat", "tan"], ["ate", "eat", "tea"]]`
# - Explanation: Words that are anagrams of each other are grouped together.
#
# **Example 2:**
# - Input: `strs = [""]`
# - Output: `[[""]]`
#
# **Example 3:**
# - Input: `strs = ["a"]`
# - Output: `[["a"]]`
#
# ### Constraints
# - `1 <= len(strs) <= 10^4`
# - `0 <= len(strs[i]) <= 100`
# - `strs[i]` consists of lowercase English letters.
#
# ### Hints
# 1. Two strings are anagrams if they have the same sorted characters — use this as a hash map key.
# 2. Alternatively, use a tuple of character counts (26 entries) as the key.

# %%
def group_anagrams(strs: list[str]) -> list[list[str]]:
    pass


# Test cases (compare as sets of frozensets for order independence)
def check_anagram_groups(result, expected):
    if result is None:
        return False
    return set(frozenset(g) for g in result) == set(frozenset(g) for g in expected)

print("PASS" if check_anagram_groups(
    group_anagrams(["eat", "tea", "tan", "ate", "nat", "bat"]),
    [["bat"], ["nat", "tan"], ["ate", "eat", "tea"]]
) else "FAIL")
print("PASS" if check_anagram_groups(group_anagrams([""]), [[""]]) else "FAIL")
print("PASS" if check_anagram_groups(group_anagrams(["a"]), [["a"]]) else "FAIL")

# %% [markdown]
# ## Problem 8: Subarray Sum Equals K [Medium] — LeetCode #560
#
# Given an array of integers `nums` and an integer `k`, return the **total number of subarrays** whose sum equals `k`.
#
# A subarray is a contiguous non-empty sequence of elements within an array.
#
# ### Examples
#
# **Example 1:**
# - Input: `nums = [1, 1, 1]`, `k = 2`
# - Output: `2`
# - Explanation: Subarrays `[1, 1]` at indices (0,1) and (1,2).
#
# **Example 2:**
# - Input: `nums = [1, 2, 3]`, `k = 3`
# - Output: `2`
# - Explanation: Subarrays `[1, 2]` and `[3]`.
#
# **Example 3:**
# - Input: `nums = [1, -1, 0]`, `k = 0`
# - Output: `3`
# - Explanation: `[1, -1]`, `[1, -1, 0]`, and `[0]`.
#
# ### Constraints
# - `1 <= len(nums) <= 2 * 10^4`
# - `-1000 <= nums[i] <= 1000`
# - `-10^7 <= k <= 10^7`
#
# ### Hints
# 1. Use a prefix sum approach: if `prefix[j] - prefix[i] == k`, then the subarray from `i` to `j` sums to `k`.
# 2. Store prefix sum counts in a hash map. At each position, check how many times `current_prefix - k` has appeared.

# %%
def subarray_sum(nums: list[int], k: int) -> int:
    pass


# Test cases
print("PASS" if subarray_sum([1, 1, 1], 2) == 2 else "FAIL")
print("PASS" if subarray_sum([1, 2, 3], 3) == 2 else "FAIL")
print("PASS" if subarray_sum([1, -1, 0], 0) == 3 else "FAIL")
print("PASS" if subarray_sum([1], 1) == 1 else "FAIL")
print("PASS" if subarray_sum([1], 0) == 0 else "FAIL")

# %% [markdown]
# ## Problem 9: Minimum Window Substring [Hard] — LeetCode #76
#
# Given two strings `s` and `t` of lengths `m` and `n` respectively, return the **minimum window substring** of `s` such that every character in `t` (including duplicates) is included in the window. If there is no such substring, return the empty string `""`.
#
# ### Examples
#
# **Example 1:**
# - Input: `s = "ADOBECODEBANC"`, `t = "ABC"`
# - Output: `"BANC"`
# - Explanation: The minimum window containing A, B, and C is "BANC".
#
# **Example 2:**
# - Input: `s = "a"`, `t = "a"`
# - Output: `"a"`
#
# **Example 3:**
# - Input: `s = "a"`, `t = "aa"`
# - Output: `""`
# - Explanation: Both `a`'s from `t` must be in the window, but `s` only has one `a`.
#
# ### Constraints
# - `1 <= len(s), len(t) <= 10^5`
# - `s` and `t` consist of uppercase and lowercase English letters.
#
# ### Hints
# 1. Use a sliding window with two pointers. Expand the right pointer to include characters, shrink the left to minimize.
# 2. Maintain a hash map of character counts needed. Track how many required characters are satisfied.

# %%
def min_window(s: str, t: str) -> str:
    pass


# Test cases
print("PASS" if min_window("ADOBECODEBANC", "ABC") == "BANC" else "FAIL")
print("PASS" if min_window("a", "a") == "a" else "FAIL")
print("PASS" if min_window("a", "aa") == "" else "FAIL")
print("PASS" if min_window("aa", "aa") == "aa" else "FAIL")
print("PASS" if min_window("abc", "d") == "" else "FAIL")

# %% [markdown]
# ## Problem 10: Longest Substring with At Most K Distinct Characters [Medium] — LeetCode #340
#
# Given a string `s` and an integer `k`, return the length of the **longest substring** that contains at most `k` distinct characters.
#
# ### Examples
#
# **Example 1:**
# - Input: `s = "eceba"`, `k = 2`
# - Output: `3`
# - Explanation: The substring is `"ece"` with length 3 (2 distinct characters: e, c).
#
# **Example 2:**
# - Input: `s = "aa"`, `k = 1`
# - Output: `2`
# - Explanation: The entire string has only 1 distinct character.
#
# **Example 3:**
# - Input: `s = "aabacbebebe"`, `k = 3`
# - Output: `7`
# - Explanation: The substring is `"cbebebe"` with 3 distinct characters.
#
# ### Constraints
# - `1 <= len(s) <= 5 * 10^4`
# - `0 <= k <= 50`
#
# ### Hints
# 1. Use a sliding window with a hash map tracking character counts in the current window.
# 2. When the window has more than `k` distinct characters, shrink from the left until it's valid again.

# %%
def length_of_longest_substring_k_distinct(s: str, k: int) -> int:
    pass


# Test cases
print("PASS" if length_of_longest_substring_k_distinct("eceba", 2) == 3 else "FAIL")
print("PASS" if length_of_longest_substring_k_distinct("aa", 1) == 2 else "FAIL")
print("PASS" if length_of_longest_substring_k_distinct("aabacbebebe", 3) == 7 else "FAIL")
print("PASS" if length_of_longest_substring_k_distinct("a", 0) == 0 else "FAIL")
print("PASS" if length_of_longest_substring_k_distinct("abcdef", 6) == 6 else "FAIL")
