# %% [markdown]
# # Topic 4: Stacks & Queues — Practice Problems
#
# Solve these problems using the patterns from the main notebook. No solutions provided — work through them yourself!

# %% [markdown]
# ## Problem 1: Implement Stack using Queues [Easy] — LeetCode #225
#
# Implement a last-in-first-out (LIFO) stack using only two queues. The implemented stack should support all the functions of a normal stack: `push`, `top`, `pop`, and `empty`.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:
#   push(1), push(2), top(), pop(), empty()
# Output:
#   None, None, 2, 2, False
# ```
#
# ### Constraints
# - `1 <= x <= 9`
# - At most 100 calls to `push`, `pop`, `top`, and `empty`
# - All calls to `pop` and `top` are valid (stack is not empty)
#
# ### Hints
# 1. On each push, you can make the new element the front of the queue by rotating.
# 2. Alternative: make pop expensive by moving all but the last element to the other queue.

# %%
from collections import deque


class MyStack:
    def __init__(self):
        pass

    def push(self, x: int) -> None:
        pass

    def pop(self) -> int:
        pass

    def top(self) -> int:
        pass

    def empty(self) -> bool:
        pass


# --- Test Cases ---
s = MyStack()
s.push(1)
s.push(2)
print("PASS" if s.top() == 2 else "FAIL", "| Test 1 (top)")
print("PASS" if s.pop() == 2 else "FAIL", "| Test 2 (pop)")
print("PASS" if s.empty() == False else "FAIL", "| Test 3 (not empty)")
print("PASS" if s.pop() == 1 else "FAIL", "| Test 4 (pop last)")
print("PASS" if s.empty() == True else "FAIL", "| Test 5 (empty)")

# %% [markdown]
# ## Problem 2: Backspace String Compare [Easy] — LeetCode #844
#
# Given two strings `s` and `t`, return `True` if they are equal when both are typed into empty text editors. `#` means a backspace character (deletes the previous character).
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  s = "ab#c", t = "ad#c"
# Output: True
# Explanation: Both become "ac".
# ```
#
# **Example 2:**
# ```
# Input:  s = "ab##", t = "c#d#"
# Output: True
# Explanation: Both become "".
# ```
#
# **Example 3:**
# ```
# Input:  s = "a#c", t = "b"
# Output: False
# Explanation: s becomes "c", t becomes "b".
# ```
#
# ### Constraints
# - `1 <= len(s), len(t) <= 200`
# - `s` and `t` only contain lowercase letters and '#'
#
# ### Hints
# 1. Use a stack: push characters, pop on '#'.
# 2. For O(1) space: iterate from the back, counting skips.

# %%
def backspace_compare(s: str, t: str) -> bool:
    """Return True if both strings are equal after processing backspaces."""
    pass


# --- Test Cases ---
print("PASS" if backspace_compare("ab#c", "ad#c") == True else "FAIL", "| Test 1")
print("PASS" if backspace_compare("ab##", "c#d#") == True else "FAIL", "| Test 2")
print("PASS" if backspace_compare("a#c", "b") == False else "FAIL", "| Test 3")
print("PASS" if backspace_compare("a##c", "#a#c") == True else "FAIL", "| Test 4 (extra backspaces)")
print("PASS" if backspace_compare("abc", "abc") == True else "FAIL", "| Test 5 (no backspaces)")

# %% [markdown]
# ## Problem 3: Next Greater Element I [Easy] — LeetCode #496
#
# The **next greater element** of an element `x` in an array is the first element that is greater than `x` to its right.
#
# You are given two distinct 0-indexed integer arrays `nums1` and `nums2`, where `nums1` is a subset of `nums2`. For each `nums1[i]`, find its next greater element in `nums2`. If it doesn't exist, return -1.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  nums1 = [4,1,2], nums2 = [1,3,4,2]
# Output: [-1,3,-1]
# Explanation: For 4 → no greater to its right. For 1 → 3. For 2 → no greater to its right.
# ```
#
# **Example 2:**
# ```
# Input:  nums1 = [2,4], nums2 = [1,2,3,4]
# Output: [3,-1]
# ```
#
# ### Constraints
# - `1 <= len(nums1) <= len(nums2) <= 1000`
# - All integers in `nums1` and `nums2` are unique
# - All integers of `nums1` also appear in `nums2`
#
# ### Hints
# 1. Use a **monotonic decreasing stack** to find the next greater element for every element in `nums2`.
# 2. Store the results in a hash map, then look up each element of `nums1`.

# %%
def next_greater_element(nums1: list[int], nums2: list[int]) -> list[int]:
    """For each element in nums1, find its next greater element in nums2."""
    pass


# --- Test Cases ---
print("PASS" if next_greater_element([4,1,2], [1,3,4,2]) == [-1,3,-1] else "FAIL", "| Test 1")
print("PASS" if next_greater_element([2,4], [1,2,3,4]) == [3,-1] else "FAIL", "| Test 2")
print("PASS" if next_greater_element([1], [1]) == [-1] else "FAIL", "| Test 3 (single element)")
print("PASS" if next_greater_element([1,3,5], [1,3,5,7]) == [3,5,7] else "FAIL", "| Test 4")

# %% [markdown]
# ## Problem 4: Online Stock Span [Medium] — LeetCode #901
#
# Design an algorithm that collects daily price quotes for some stock and returns the **span** of that stock's price for the current day.
#
# The span of the stock's price on a given day is the maximum number of consecutive days (starting from that day and going backward) for which the stock price was **less than or equal to** the price of that day.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  prices called in order: [100, 80, 60, 70, 60, 75, 85]
# Output: spans:                  [1,   1,  1,  2,  1,  4,  6]
# ```
#
# ### Constraints
# - `1 <= price <= 10^5`
# - At most `10^4` calls to `next`
#
# ### Hints
# 1. Use a monotonic decreasing stack that stores `(price, span)` pairs.
# 2. When a new price comes in, pop all stack entries with price ≤ current, accumulating their spans.

# %%
class StockSpanner:
    def __init__(self):
        pass

    def next(self, price: int) -> int:
        pass


# --- Test Cases ---
sp = StockSpanner()
results = []
for price in [100, 80, 60, 70, 60, 75, 85]:
    results.append(sp.next(price))
print("PASS" if results == [1, 1, 1, 2, 1, 4, 6] else "FAIL", "| Test 1")

sp2 = StockSpanner()
results2 = []
for price in [10, 20, 30, 40, 50]:
    results2.append(sp2.next(price))
print("PASS" if results2 == [1, 2, 3, 4, 5] else "FAIL", "| Test 2 (always increasing)")

sp3 = StockSpanner()
results3 = []
for price in [50, 40, 30, 20, 10]:
    results3.append(sp3.next(price))
print("PASS" if results3 == [1, 1, 1, 1, 1] else "FAIL", "| Test 3 (always decreasing)")

# %% [markdown]
# ## Problem 5: Asteroid Collision [Medium] — LeetCode #735
#
# We are given an array `asteroids` of integers representing asteroids in a row. For each asteroid, the absolute value represents its size, and the sign represents its direction (positive = right, negative = left). Each asteroid moves at the same speed.
#
# When two asteroids meet, the smaller one explodes. If both are the same size, both explode. Two asteroids moving in the same direction never meet.
#
# Return the state of the asteroids after all collisions.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  asteroids = [5, 10, -5]
# Output: [5, 10]
# Explanation: 10 and -5 collide → 10 survives. 5 and 10 never collide.
# ```
#
# **Example 2:**
# ```
# Input:  asteroids = [8, -8]
# Output: []
# Explanation: 8 and -8 collide → both explode.
# ```
#
# **Example 3:**
# ```
# Input:  asteroids = [10, 2, -5]
# Output: [10]
# Explanation: 2 and -5 collide → -5 survives. 10 and -5 collide → 10 survives.
# ```
#
# ### Constraints
# - `2 <= len(asteroids) <= 10^4`
# - `-1000 <= asteroids[i] <= 1000`
# - `asteroids[i] != 0`
#
# ### Hints
# 1. Use a stack. Only collisions happen when stack top is positive and incoming is negative.
# 2. Simulate collisions: pop if the incoming asteroid is bigger, skip it if smaller, pop both if equal.

# %%
def asteroid_collision(asteroids: list[int]) -> list[int]:
    """Return the state of asteroids after all collisions."""
    pass


# --- Test Cases ---
print("PASS" if asteroid_collision([5, 10, -5]) == [5, 10] else "FAIL", "| Test 1")
print("PASS" if asteroid_collision([8, -8]) == [] else "FAIL", "| Test 2")
print("PASS" if asteroid_collision([10, 2, -5]) == [10] else "FAIL", "| Test 3")
print("PASS" if asteroid_collision([-2, -1, 1, 2]) == [-2, -1, 1, 2] else "FAIL", "| Test 4 (no collision)")
print("PASS" if asteroid_collision([1, -1, 1, -1]) == [] else "FAIL", "| Test 5 (all cancel)")

# %% [markdown]
# ## Problem 6: Decode String [Medium] — LeetCode #394
#
# Given an encoded string, return its decoded string.
#
# The encoding rule is: `k[encoded_string]`, where the `encoded_string` inside the brackets is repeated exactly `k` times. You may assume the input is always valid.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  s = "3[a]2[bc]"
# Output: "aaabcbc"
# ```
#
# **Example 2:**
# ```
# Input:  s = "3[a2[c]]"
# Output: "accaccacc"
# ```
#
# **Example 3:**
# ```
# Input:  s = "2[abc]3[cd]ef"
# Output: "abcabccdcdcdef"
# ```
#
# ### Constraints
# - `1 <= len(s) <= 30`
# - `s` consists of lowercase English letters, digits, and brackets `[]`
# - `1 <= k <= 300`
#
# ### Hints
# 1. Use two stacks: one for counts, one for strings built so far.
# 2. On `[`, push current string and count. On `]`, pop and build the repeated string.

# %%
def decode_string(s: str) -> str:
    """Decode the encoded string."""
    pass


# --- Test Cases ---
print("PASS" if decode_string("3[a]2[bc]") == "aaabcbc" else "FAIL", "| Test 1")
print("PASS" if decode_string("3[a2[c]]") == "accaccacc" else "FAIL", "| Test 2 (nested)")
print("PASS" if decode_string("2[abc]3[cd]ef") == "abcabccdcdcdef" else "FAIL", "| Test 3")
print("PASS" if decode_string("abc") == "abc" else "FAIL", "| Test 4 (no encoding)")
print("PASS" if decode_string("10[a]") == "aaaaaaaaaa" else "FAIL", "| Test 5 (multi-digit k)")

# %% [markdown]
# ## Problem 7: Remove K Digits [Medium] — LeetCode #402
#
# Given string `num` representing a non-negative integer and an integer `k`, return the smallest possible integer after removing `k` digits from `num`.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  num = "1432219", k = 3
# Output: "1219"
# Explanation: Remove 4, 3, 2 → "1219"
# ```
#
# **Example 2:**
# ```
# Input:  num = "10200", k = 1
# Output: "200"
# ```
#
# **Example 3:**
# ```
# Input:  num = "10", k = 2
# Output: "0"
# ```
#
# ### Constraints
# - `1 <= k <= len(num) <= 10^5`
# - `num` consists of only digits and does not have leading zeros (except for "0" itself)
#
# ### Hints
# 1. Use a **monotonically increasing stack**. When the current digit is smaller than the stack top, pop (this removes a larger digit).
# 2. Handle edge cases: remaining removals after the loop, leading zeros in the result.

# %%
def remove_k_digits(num: str, k: int) -> str:
    """Return the smallest number after removing k digits."""
    pass


# --- Test Cases ---
print("PASS" if remove_k_digits("1432219", 3) == "1219" else "FAIL", "| Test 1")
print("PASS" if remove_k_digits("10200", 1) == "200" else "FAIL", "| Test 2")
print("PASS" if remove_k_digits("10", 2) == "0" else "FAIL", "| Test 3")
print("PASS" if remove_k_digits("9", 1) == "0" else "FAIL", "| Test 4 (single digit)")
print("PASS" if remove_k_digits("112", 1) == "11" else "FAIL", "| Test 5")

# %% [markdown]
# ## Problem 8: Simplify Path [Medium] — LeetCode #71
#
# Given an absolute Unix-style file path, simplify it. The rules are:
# - `.` refers to the current directory
# - `..` refers to the parent directory
# - Multiple consecutive slashes `//` are treated as a single `/`
# - The canonical path should start with `/` and not end with `/` (unless it's the root)
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  path = "/home/"
# Output: "/home"
# ```
#
# **Example 2:**
# ```
# Input:  path = "/home//foo/"
# Output: "/home/foo"
# ```
#
# **Example 3:**
# ```
# Input:  path = "/home/user/Documents/../Pictures"
# Output: "/home/user/Pictures"
# ```
#
# **Example 4:**
# ```
# Input:  path = "/../"
# Output: "/"
# Explanation: Can't go above root.
# ```
#
# ### Constraints
# - `1 <= len(path) <= 3000`
# - `path` consists of English letters, digits, `.`, `/`, or `_`
#
# ### Hints
# 1. Split by `/`, use a stack: push directory names, pop on `..`, ignore `.` and empty strings.
# 2. Join the stack with `/` at the end.

# %%
def simplify_path(path: str) -> str:
    """Simplify the given Unix-style absolute path."""
    pass


# --- Test Cases ---
print("PASS" if simplify_path("/home/") == "/home" else "FAIL", "| Test 1")
print("PASS" if simplify_path("/home//foo/") == "/home/foo" else "FAIL", "| Test 2")
print("PASS" if simplify_path("/home/user/Documents/../Pictures") == "/home/user/Pictures" else "FAIL", "| Test 3")
print("PASS" if simplify_path("/../") == "/" else "FAIL", "| Test 4 (above root)")
print("PASS" if simplify_path("/a/./b/../../c/") == "/c" else "FAIL", "| Test 5")

# %% [markdown]
# ## Problem 9: Trapping Rain Water (Stack Approach) [Hard] — LeetCode #42
#
# Given `n` non-negative integers representing an elevation map where the width of each bar is 1, compute how much water it can trap after raining.
#
# **This time, solve it using a stack-based approach** (different from the two-pointer method in notebook 02).
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  height = [0,1,0,2,1,0,1,3,2,1,2,1]
# Output: 6
# ```
#
# **Example 2:**
# ```
# Input:  height = [4,2,0,3,2,5]
# Output: 9
# ```
#
# ### Constraints
# - `n == len(height)`
# - `1 <= n <= 2 * 10^4`
# - `0 <= height[i] <= 10^5`
#
# ### Hints
# 1. Use a **monotonically decreasing stack** of indices.
# 2. When `height[i] > height[stack[-1]]`, we've found a "bowl" — pop the top, compute the water trapped between the new top and `i`, layer by layer.

# %%
def trap_stack(height: list[int]) -> int:
    """Compute trapped water using a stack-based approach."""
    pass


# --- Test Cases ---
print("PASS" if trap_stack([0,1,0,2,1,0,1,3,2,1,2,1]) == 6 else "FAIL", "| Test 1")
print("PASS" if trap_stack([4,2,0,3,2,5]) == 9 else "FAIL", "| Test 2")
print("PASS" if trap_stack([1,2,3,4,5]) == 0 else "FAIL", "| Test 3 (ascending)")
print("PASS" if trap_stack([3,0,3]) == 3 else "FAIL", "| Test 4")
print("PASS" if trap_stack([2,0,2]) == 2 else "FAIL", "| Test 5")

# %% [markdown]
# ## Problem 10: Basic Calculator II [Medium] — LeetCode #227
#
# Given a string `s` representing a mathematical expression, evaluate it and return its value. The expression contains non-negative integers, `+`, `-`, `*`, `/` operators, and spaces. Integer division should truncate toward zero.
#
# **Note:** You may not use the built-in `eval()` function.
#
# ### Examples
#
# **Example 1:**
# ```
# Input:  s = "3+2*2"
# Output: 7
# ```
#
# **Example 2:**
# ```
# Input:  s = " 3/2 "
# Output: 1
# ```
#
# **Example 3:**
# ```
# Input:  s = " 3+5 / 2 "
# Output: 5
# ```
#
# ### Constraints
# - `1 <= len(s) <= 3 * 10^5`
# - `s` consists of digits, `+`, `-`, `*`, `/`, and spaces
# - `s` represents a valid expression
#
# ### Hints
# 1. Use a stack for values. Track the previous operator. Apply `*` and `/` immediately (they bind tighter), push `+`/`-` values onto the stack.
# 2. At the end, sum everything in the stack.

# %%
def calculate(s: str) -> int:
    """Evaluate a basic arithmetic expression (no parentheses)."""
    pass


# --- Test Cases ---
print("PASS" if calculate("3+2*2") == 7 else "FAIL", "| Test 1")
print("PASS" if calculate(" 3/2 ") == 1 else "FAIL", "| Test 2")
print("PASS" if calculate(" 3+5 / 2 ") == 5 else "FAIL", "| Test 3")
print("PASS" if calculate("42") == 42 else "FAIL", "| Test 4 (single number)")
print("PASS" if calculate("14-3/2") == 13 else "FAIL", "| Test 5")
